# %% [markdown]
# # Analyzing DreamWorks Animated Movie Transcripts
#
# **Student Name:** Noppachon Chaisongkhram
#
# **Student ID:** 300607581
#
# **Course:** LSCI 220
#
#
# ## Introduction
# This corpus consists of 10 DreamWorks animated movie transcripts released during the 2000s.
#
# **Texts included:**
# 1. Shrek (2001)
# 2. Madagascar (2005)
# 3. Bee Movie (2007)
# 4. Kung Fu Panda (2008)
# 5. Madagascar 2 (2008)
# 6. Monsters vs Aliens (2009)
# 7. How to Train Your Dragon (2010)
# 8. Megamind (2010)
# 9. Kung Fu Panda 2 (2011)
# 10. Puss in Boots (2011)
#
#
# **Research questions:**
# - Do comedy-focused films (Bee Movie) have higher lexical diversity than action films (Kung Fu Panda)?
# - How do character names distribution differ across films?
# - Are there gender differences in dialogue distribution?

# %%
from nltk.corpus import PlaintextCorpusReader, stopwords

# %%
import os

# Path to transcripts
corpus_root = './transcripts'

if not os.path.exists(corpus_root):
    print(f"Error: Directory '{corpus_root}' not found!")
else:
    # Load
    movie_corpus = PlaintextCorpusReader(corpus_root, r'.*\.txt')  # Raw string

    # Corpus check
    print("Corpus loaded successfully!")
    print(f"Number of texts: {len(movie_corpus.fileids())}")
    print(f"File IDs: {movie_corpus.fileids()}")
# Out:
# Corpus loaded successfully!
# Number of texts: 10
# File IDs: ['Bee Movie (2007).txt', 'How to Train Your Dragon (2010).txt', 'Kung Fu Panda (2008).txt', 'Kung Fu Panda 2 (2011).txt', 'Madagascar (2005).txt', 'Madagascar 2 (2008).txt', 'Megamind (2010).txt', 'Monsters vs Aliens (2009).txt', 'Puss in Boots (2011).txt', 'Shrek (2001).txt']
